# %%
#!pip install xarray
#!pip install scipy
#!pip install cdsapi

# %% [markdown]
# #### Import Libraries

# %%
import xarray as xr
import numpy as np
import pandas as pd
import marineHeatWaves as mhw
import datetime as dt
import math

import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from scipy.interpolate import griddata
from matplotlib.gridspec import GridSpec

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %% [markdown]
# #### Define Slice Function

# %% [markdown]
# The coordinates have to be defined in 0-360 format.

# %%
def spatial_subset(ds):
    out = ds.sel(lon = slice(350.0, 355.0),
                 lat = slice(36.0, 42.3))
    return out

# %% [markdown]
# ## Get Baseline

# %% [markdown]
# The baselilne used is 1991-2021

# %%
baseline_df = pd.DataFrame()
for year in range(1981, 2024):

    var = xr.open_dataset(f"oisst_daily/sst.day.mean.{year}.nc", 
                        engine="netcdf4", decode_times=True)
    
    print(f'Opening {year}')
    
    var_sel = spatial_subset(var)
    
    var_sst = var_sel["sst"]

    baseline_df = pd.concat([baseline_df, var_sst.to_dataframe()])
    
del var
# Out:
# Opening 1981
# Opening 1982
# Opening 1983
# Opening 1984
# Opening 1985
# Opening 1986
# Opening 1987
# Opening 1988
# Opening 1989
# Opening 1990
# Opening 1991
# Opening 1992
# Opening 1993
# Opening 1994
# Opening 1995
# Opening 1996
# Opening 1997
# Opening 1998
# Opening 1999
# Opening 2000
# Opening 2001
# Opening 2002
# Opening 2003
# Opening 2004
# Opening 2005
# Opening 2006
# Opening 2007
# Opening 2008
# Opening 2009
# Opening 2010
# Opening 2011
# Opening 2012
# Opening 2013
# Opening 2014
# Opening 2015
# Opening 2016
# Opening 2017
# Opening 2018
# Opening 2019
# Opening 2020
# Opening 2021
# Opening 2022
# Opening 2023

# %% [markdown]
# ## Years to be Analysed

# %%
y2024 = xr.open_dataset("oisst_daily/sst.day.mean.2024.nc", 
                        engine="netcdf4", decode_times=True)

# %% [markdown]
# #### Slice datasets' coordinates

# %%
y2024_sel = spatial_subset(y2024)
y2024_sst = y2024_sel["sst"]
y2024_time = y2024_sel["time"]

# %%
baseline_df = baseline_df.reset_index()

y2024_df = y2024_sst.to_dataframe().reset_index()

# %% [markdown]
# ## Conversion to ordinal time

# %%
def to_ordinal(time_array):
    ordinals = []

    for t in time_array:
        # Case 1: numpy.datetime64
        if isinstance(t, np.datetime64):
            ts = pd.Timestamp(t)
            ordinals.append(ts.to_pydatetime().date().toordinal())

        # Case 2: cftime objects
        else:
            ordinals.append(dt.date(t.year, t.month, t.day).toordinal())

    return np.array(ordinals)

# %% [markdown]
# ## Detect MHWs

# %%
y2024_time_ord = to_ordinal(y2024_df['time'])
baseline_time_ord = to_ordinal(baseline_df["time"])

# %%
results = []

for (lat, lon), group in y2024_df.groupby(["lat", "lon"]):

    # Subset baseline dataframe for this grid point
    baseline_point = (
    baseline_df
    .query("lat == @lat and lon == @lon")
    .sort_values("time")
)

    # Subset baseline time ordinals USING THE SAME ROWS
    baseline_idx = baseline_point.index.values
    baseline_time_ord_sub = baseline_time_ord[baseline_idx]
    baseline_temp = baseline_point["sst"].values


    t_ord = to_ordinal(group["time"])
    temp = group["sst"].values

    mhw_events, clim = mhw.detect(
    t_ord,
    temp,
    climatologyPeriod=[1981, 2010],
    alternateClimatology=[baseline_time_ord_sub, baseline_temp]
)


    mhw_df = pd.DataFrame(mhw_events)
    mhw_df["lat"] = lat
    mhw_df["lon"] = lon

    results.append(mhw_df)

mhw_all = pd.concat(results, ignore_index=True)
mhw_all.to_csv("mhw_events_2024.csv", index=False)
# Out:
# /var/folders/wq/98_by44j0113pwx7jtjgd74w0000gn/T/ipykernel_64013/3147003752.py:35: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   mhw_all = pd.concat(results, ignore_index=True)

# %% [markdown]
# ## MHWs Analysis

# %%
mhw_all = pd.read_csv("mhw_events_2024.csv")

# %%
mhw_all["date_start"] = pd.to_datetime(mhw_all["date_start"], errors="coerce")
mhw_all["date_end"] = pd.to_datetime(mhw_all["date_end"], errors="coerce")

# %%
mhw_all['duration'] = mhw_all['date_end'] - mhw_all['date_start']
mhw_all['duration'].head()
# Out:
# 0   145 days
# 1     4 days
# 2    36 days
# 3   144 days
# 4     4 days
# Name: duration, dtype: timedelta64[ns]

# %%
mhw_all = mhw_all.set_index(["lat", "lon"]).sort_index()
grouped = mhw_all.groupby(level=["lat", "lon"])

# %%
mhw_all.columns
# Out:
# Index(['time_start', 'time_end', 'time_peak', 'date_start', 'date_end',
#        'date_peak', 'index_start', 'index_end', 'index_peak', 'duration',
#        'duration_moderate', 'duration_strong', 'duration_severe',
#        'duration_extreme', 'intensity_max', 'intensity_mean', 'intensity_var',
#        'intensity_cumulative', 'intensity_max_relThresh',
#        'intensity_mean_relThresh', 'intensity_var_relThresh',
#        'intensity_cumulative_relThresh', 'intensity_max_abs',
#        'intensity_mean_abs', 'intensity_var_abs', 'intensity_cumulative_abs',
#        'category', 'rate_onset', 'rate_decline', 'n_events'],
#       dtype='object')

# %%
for (lat, lon), df in grouped:
    print(lat, lon)
    print(df[['date_start', 'date_end','duration', 'category']])
    print()
# Out:
# 36.125 350.125
#                date_start   date_end duration  category
# lat    lon
# 36.125 350.125 2024-01-01 2024-05-25 145 days    Severe
#        350.125 2024-11-07 2024-11-11   4 days  Moderate
#        350.125 2024-11-25 2024-12-31  36 days    Strong
#
# 36.125 350.375
#                date_start   date_end duration  category
# lat    lon
# 36.125 350.375 2024-01-01 2024-05-24 144 days    Severe
#        350.375 2024-11-07 2024-11-11   4 days  Moderate
#        350.375 2024-11-23 2024-12-31  38 days    Strong
#
# 36.125 350.625
#                date_start   date_end duration  category
# lat    lon
# 36.125 350.625 2024-01-01 2024-03-22  81 days    Severe
#        350.625 2024-04-03 2024-05-12  39 days    Strong
#        350.625 2024-10-21 2024-10-25   4 days  Moderate
#        350.625 2024-11-07 2024-11-11   4 days  Moderate
#        350.625 2024-11-22 2024-12-31  39 days    Strong
#
# 36.125 350.875
#                date_start   date_end duration  category
# lat    lon
# 36.125 350.875 2024-01-01 2024-03-22  81 days    Strong
#        350.875 2024-04-03 2024-05-11  38 days    Strong
#        350.875 2024-07-21 2024-07-25   4 days  Moderate
#        350.875 2024-10-21 2024-10-25   4 days  Moderate
#        350.875 2024-11-02 2024-11-12  10 days  Moderate
#        350.875 2024-11-17 2024-12-31  44 days    Strong
#
# 36.125 351.125
#                date_start   date_end duration  category
# lat    lon
# 36.125 351.125 2024-01-01 2024-03-04  63 days    Strong
#        351.125 2024-03-14 2024-03-29  15 days  Moderate
#        351.125 2024-04-02 2024-05-10  38 days    Strong
#        351.125 2024-07-21 2024-07-25   4 days  Moderate
#        351.125 2024-08-17 2024-08-30  13 days  Moderate
#        351.125 2024-10-21 2024-10-25   4 days  Moderate
#        351.125 2024-11-02 2024-12-31  59 days    Strong
#
# 36.125 351.375
#                date_start   date_end duration category
# lat    lon
# 36.125 351.375 2024-01-01 2024-03-04  63 days   Strong
#        351.375 2024-03-15 2024-05-10  56 days   Strong
#        351.375 2024-08-15 2024-08-30  15 days   Strong
#        351.375 2024-11-01 2024-12-31  60 days   Strong
#
# 36.125 351.625
#                date_start   date_end duration  category
# lat    lon
# 36.125 351.625 2024-01-01 2024-03-04  63 days    Strong
#        351.625 2024-03-15 2024-04-28  44 days    Strong
#        351.625 2024-05-03 2024-05-10   7 days  Moderate
#        351.625 2024-08-01 2024-09-02  32 days    Strong
#        351.625 2024-11-01 2024-12-31  60 days    Strong
#
# 36.125 351.875
#                date_start   date_end duration  category
# lat    lon
# 36.125 351.875 2024-01-01 2024-03-08  67 days    Strong
#        351.875 2024-03-14 2024-03-28  14 days  Moderate
#        351.875 2024-04-02 2024-04-27  25 days    Strong
#        351.875 2024-05-04 2024-05-11   7 days  Moderate
#        351.875 2024-07-02 2024-07-06   4 days  Moderate
#        351.875 2024-07-29 2024-09-02  35 days  Moderate
#        351.875 2024-11-02 2024-12-31  59 days    Strong
#
# 36.125 352.125
#                date_start   date_end duration  category
# lat    lon
# 36.125 352.125 2024-01-01 2024-03-28  87 days    Strong
#        352.125 2024-04-02 2024-04-26  24 days  Moderate
#        352.125 2024-05-04 2024-05-12   8 days  Moderate
#        352.125 2024-07-02 2024-07-06   4 days  Moderate
#        352.125 2024-07-22 2024-09-01  41 days    Strong
#        352.125 2024-11-04 2024-12-31  57 days    Strong
#
# 36.125 352.375
#                date_start   date_end duration  category
# lat    lon
# 36.125 352.375 2024-01-01 2024-03-23  82 days    Strong
#        352.375 2024-04-08 2024-04-26  18 days  Moderate
#        352.375 2024-07-22 2024-08-23  32 days    Strong
#        352.375 2024-11-04 2024-11-14  10 days  Moderate
#        352.375 2024-11-18 2024-12-31  43 days    Strong
#
# 36.125 352.625
#                date_start   date_end duration  category
# lat    lon
# 36.125 352.625 2024-01-01 2024-03-23  82 days    Strong
#        352.625 2024-04-09 2024-04-26  17 days  Moderate
#        352.625 2024-05-29 2024-06-02   4 days  Moderate
#        352.625 2024-07-22 2024-08-23  32 days    Strong
#        352.625 2024-11-03 2024-11-12   9 days  Moderate
#        352.625 2024-11-18 2024-12-31  43 days    Strong
#
# 36.125 352.875
#                date_start   date_end duration  category
# lat    lon
# 36.125 352.875 2024-01-01 2024-03-21  80 days    Strong
#        352.875 2024-04-14 2024-04-26  12 days  Moderate
#        352.875 2024-06-13 2024-06-17   4 days  Moderate
#        352.875 2024-07-31 2024-08-23  23 days    Strong
#        352.875 2024-11-02 2024-12-31  59 days    Strong
#
# 36.125 353.125
#                date_start   date_end duration  category
# lat    lon
# 36.125 353.125 2024-01-01 2024-03-21  80 days    Strong
#        353.125 2024-04-14 2024-04-27  13 days    Strong
#        353.125 2024-06-13 2024-06-17   4 days  Moderate
#        353.125 2024-08-02 2024-08-23  21 days  Moderate
#        353.125 2024-11-03 2024-12-31  58 days    Strong
#
# 36.125 353.375
#                date_start   date_end duration  category
# lat    lon
# 36.125 353.375 2024-01-01 2024-03-04  63 days    Strong
#        353.375 2024-04-14 2024-04-28  14 days    Strong
#        353.375 2024-08-09 2024-08-13   4 days  Moderate
#        353.375 2024-08-18 2024-08-23   5 days  Moderate
#        353.375 2024-11-05 2024-12-31  56 days    Strong
#
# 36.125 353.625
#                date_start   date_end duration  category
# lat    lon
# 36.125 353.625 2024-01-01 2024-03-03  62 days    Strong
#        353.625 2024-04-14 2024-04-30  16 days    Strong
#        353.625 2024-08-09 2024-08-13   4 days  Moderate
#        353.625 2024-08-18 2024-08-22   4 days  Moderate
#        353.625 2024-11-18 2024-12-28  40 days    Strong
#
# 36.125 353.875
#                date_start   date_end duration  category
# lat    lon
# 36.125 353.875 2024-01-01 2024-01-05   4 days  Moderate
#        353.875 2024-01-18 2024-03-01  43 days    Strong
#        353.875 2024-04-15 2024-05-05  20 days    Strong
#        353.875 2024-11-21 2024-12-23  32 days    Strong
#
# 36.125 354.125
#                date_start   date_end duration  category
# lat    lon
# 36.125 354.125 2024-01-01 2024-01-05   4 days  Moderate
#        354.125 2024-01-18 2024-02-29  42 days    Strong
#        354.125 2024-04-15 2024-04-28  13 days    Strong
#        354.125 2024-11-22 2024-12-23  31 days    Strong
#
# 36.125 354.625
#                date_start   date_end duration category
# lat    lon
# 36.125 354.625 2024-01-21 2024-02-27  37 days   Strong
#        354.625 2024-04-15 2024-04-20   5 days   Strong
#        354.625 2024-08-18 2024-09-08  21 days   Strong
#        354.625 2024-11-07 2024-12-12  35 days   Strong
#
# 36.125 354.875
#                date_start   date_end duration category
# lat    lon
# 36.125 354.875 2024-01-21 2024-02-27  37 days   Strong
#        354.875 2024-04-15 2024-04-19   4 days   Strong
#        354.875 2024-08-18 2024-09-08  21 days   Severe
#        354.875 2024-11-06 2024-12-13  37 days   Strong
#
# 36.375 350.125
#                date_start   date_end duration  category
# lat    lon
# 36.375 350.125 2024-01-01 2024-03-29  88 days    Severe
#        350.125 2024-04-02 2024-05-25  53 days    Strong
#        350.125 2024-11-07 2024-11-12   5 days  Moderate
#        350.125 2024-11-21 2024-12-31  40 days    Strong
#
# 36.375 350.375
#                date_start   date_end duration  category
# lat    lon
# 36.375 350.375 2024-01-01 2024-03-28  87 days    Severe
#        350.375 2024-04-03 2024-05-25  52 days    Strong
#        350.375 2024-11-02 2024-11-12  10 days  Moderate
#        350.375 2024-11-18 2024-12-31  43 days    Strong
#
# 36.375 350.625
#                date_start   date_end duration  category
# lat    lon
# 36.375 350.625 2024-01-01 2024-03-21  80 days    Severe
#        350.625 2024-04-03 2024-05-12  39 days    Strong
#        350.625 2024-11-01 2024-11-13  12 days  Moderate
#        350.625 2024-11-17 2024-12-31  44 days    Strong
#
# 36.375 350.875
#                date_start   date_end duration  category
# lat    lon
# 36.375 350.875 2024-01-01 2024-03-04  63 days    Severe
#        350.875 2024-03-14 2024-03-20   6 days  Moderate
#        350.875 2024-04-03 2024-05-11  38 days    Strong
#        350.875 2024-10-21 2024-10-26   5 days  Moderate
#        350.875 2024-11-01 2024-12-31  60 days    Strong
#
# 36.375 351.125
#                date_start   date_end duration  category
# lat    lon
# 36.375 351.125 2024-01-01 2024-03-03  62 days    Strong
#        351.125 2024-04-02 2024-05-10  38 days    Strong
#        351.125 2024-10-21 2024-10-26   5 days  Moderate
#        351.125 2024-10-31 2024-12-31  61 days    Strong
#
# 36.375 351.375
#                date_start   date_end duration  category
# lat    lon
# 36.375 351.375 2024-01-01 2024-03-03  62 days    Strong
#        351.375 2024-03-18 2024-03-29  11 days  Moderate
#        351.375 2024-04-02 2024-05-10  38 days    Strong
#        351.375 2024-10-21 2024-10-26   5 days  Moderate
#        351.375 2024-11-01 2024-12-31  60 days    Strong
#
# 36.375 351.625
#                date_start   date_end duration  category
# lat    lon
# 36.375 351.625 2024-01-01 2024-03-08  67 days    Strong
#        351.625 2024-03-15 2024-03-28  13 days  Moderate
#        351.625 2024-04-02 2024-04-28  26 days  Moderate
#        351.625 2024-05-03 2024-05-11   8 days  Moderate
#        351.625 2024-11-03 2024-12-31  58 days    Strong
#
# 36.375 351.875
#                date_start   date_end duration  category
# lat    lon
# 36.375 351.875 2024-01-01 2024-03-09  68 days    Strong
#        351.875 2024-03-15 2024-03-28  13 days  Moderate
#        351.875 2024-04-02 2024-04-27  25 days    Strong
#        351.875 2024-05-07 2024-05-12   5 days  Moderate
#        351.875 2024-05-29 2024-06-02   4 days  Moderate
#        351.875 2024-11-04 2024-12-31  57 days    Strong
#
# 36.375 352.125
#                date_start   date_end duration  category
# lat    lon
# 36.375 352.125 2024-01-01 2024-03-27  86 days    Strong
#        352.125 2024-04-03 2024-04-27  24 days    Strong
#        352.125 2024-05-07 2024-05-12   5 days  Moderate
#        352.125 2024-05-28 2024-06-03   6 days  Moderate
#        352.125 2024-08-04 2024-08-12   8 days  Moderate
#        352.125 2024-11-05 2024-12-31  56 days    Strong
#
# 36.375 352.375
#                date_start   date_end duration  category
# lat    lon
# 36.375 352.375 2024-01-01 2024-03-27  86 days    Strong
#        352.375 2024-04-08 2024-04-26  18 days    Strong
#        352.375 2024-05-07 2024-05-12   5 days  Moderate
#        352.375 2024-05-28 2024-06-05   8 days  Moderate
#        352.375 2024-08-04 2024-08-13   9 days  Moderate
#        352.375 2024-11-04 2024-12-31  57 days    Strong
#
# 36.375 352.625
#                date_start   date_end duration  category
# lat    lon
# 36.375 352.625 2024-01-01 2024-03-23  82 days    Strong
#        352.625 2024-04-08 2024-04-26  18 days    Strong
#        352.625 2024-05-29 2024-06-05   7 days  Moderate
#        352.625 2024-08-05 2024-08-13   8 days  Moderate
#        352.625 2024-11-03 2024-12-31  58 days    Strong
#
# 36.375 352.875
#                date_start   date_end duration  category
# lat    lon
# 36.375 352.875 2024-01-01 2024-03-21  80 days    Strong
#        352.875 2024-04-09 2024-04-27  18 days    Strong
#        352.875 2024-08-06 2024-08-13   7 days  Moderate
#        352.875 2024-11-03 2024-12-31  58 days    Strong
#
# 36.375 353.125
#                date_start   date_end duration  category
# lat    lon
# 36.375 353.125 2024-01-01 2024-03-09  68 days    Strong
#        353.125 2024-03-13 2024-03-21   8 days  Moderate
#        353.125 2024-04-10 2024-04-28  18 days    Strong
#        353.125 2024-08-17 2024-08-21   4 days  Moderate
#        353.125 2024-11-04 2024-12-31  57 days    Strong
#
# 36.375 353.375
#                date_start   date_end duration  category
# lat    lon
# 36.375 353.375 2024-01-01 2024-03-03  62 days    Strong
#        353.375 2024-04-10 2024-04-30  20 days    Strong
#        353.375 2024-08-09 2024-08-21  12 days  Moderate
#        353.375 2024-11-14 2024-12-27  43 days    Strong
#
# 36.375 353.625
#                date_start   date_end duration  category
# lat    lon
# 36.375 353.625 2024-01-22 2024-02-29  38 days  Moderate
#        353.625 2024-04-14 2024-04-30  16 days    Strong
#        353.625 2024-08-09 2024-09-02  24 days  Moderate
#        353.625 2024-11-23 2024-12-09  16 days  Moderate
#
# 36.375 353.875
#                date_start   date_end duration  category
# lat    lon
# 36.375 353.875 2024-01-23 2024-02-28  36 days  Moderate
#        353.875 2024-04-14 2024-05-05  21 days    Strong
#        353.875 2024-08-15 2024-08-21   6 days  Moderate
#        353.875 2024-11-25 2024-12-08  13 days  Moderate
#
# 36.375 354.875
#                date_start   date_end duration  category
# lat    lon
# 36.375 354.875 2024-01-23 2024-02-11  19 days  Moderate
#        354.875 2024-02-16 2024-02-26  10 days    Strong
#        354.875 2024-04-14 2024-04-26  12 days  Moderate
#        354.875 2024-08-09 2024-08-13   4 days  Moderate
#        354.875 2024-08-17 2024-09-09  23 days    Severe
#        354.875 2024-11-05 2024-12-11  36 days    Strong
#
# 36.625 350.125
#                date_start   date_end duration  category
# lat    lon
# 36.625 350.125 2024-01-01 2024-03-28  87 days    Strong
#        350.125 2024-04-02 2024-05-29  57 days    Strong
#        350.125 2024-11-06 2024-11-12   6 days  Moderate
#        350.125 2024-11-19 2024-12-31  42 days    Strong
#
# 36.625 350.375
#                date_start   date_end duration  category
# lat    lon
# 36.625 350.375 2024-01-01 2024-03-24  83 days    Strong
#        350.375 2024-04-03 2024-05-25  52 days    Strong
#        350.375 2024-11-02 2024-11-13  11 days  Moderate
#        350.375 2024-11-18 2024-12-31  43 days    Strong
#
# 36.625 350.625
#                date_start   date_end duration  category
# lat    lon
# 36.625 350.625 2024-01-01 2024-03-09  68 days    Severe
#        350.625 2024-03-13 2024-03-17   4 days  Moderate
#        350.625 2024-04-03 2024-05-12  39 days    Strong
#        350.625 2024-11-02 2024-12-31  59 days    Strong
#
# 36.625 350.875
#                date_start   date_end duration category
# lat    lon
# 36.625 350.875 2024-01-01 2024-03-03  62 days   Severe
#        350.875 2024-04-03 2024-05-10  37 days   Strong
#        350.875 2024-11-02 2024-12-31  59 days   Strong
#
# 36.625 351.125
#                date_start   date_end duration  category
# lat    lon
# 36.625 351.125 2024-01-01 2024-03-02  61 days    Strong
#        351.125 2024-04-03 2024-04-30  27 days  Moderate
#        351.125 2024-11-04 2024-12-31  57 days    Strong
#
# 36.625 351.375
#                date_start   date_end duration  category
# lat    lon
# 36.625 351.375 2024-01-01 2024-03-03  62 days    Strong
#        351.375 2024-04-03 2024-04-28  25 days  Moderate
#        351.375 2024-06-03 2024-06-09   6 days  Moderate
#        351.375 2024-11-05 2024-12-31  56 days    Strong
#
# 36.625 351.625
#                date_start   date_end duration  category
# lat    lon
# 36.625 351.625 2024-01-01 2024-03-08  67 days    Strong
#        351.625 2024-04-03 2024-04-28  25 days  Moderate
#        351.625 2024-05-29 2024-06-09  11 days  Moderate
#        351.625 2024-11-07 2024-12-31  54 days    Strong
#
# 36.625 351.875
#                date_start   date_end duration  category
# lat    lon
# 36.625 351.875 2024-01-01 2024-03-09  68 days    Strong
#        351.875 2024-04-07 2024-04-27  20 days    Strong
#        351.875 2024-05-29 2024-06-09  11 days  Moderate
#        351.875 2024-11-17 2024-12-31  44 days    Strong
#
# 36.625 352.125
#                date_start   date_end duration  category
# lat    lon
# 36.625 352.125 2024-01-01 2024-03-09  68 days    Strong
#        352.125 2024-03-15 2024-03-21   6 days  Moderate
#        352.125 2024-04-08 2024-04-27  19 days    Strong
#        352.125 2024-05-29 2024-06-09  11 days  Moderate
#        352.125 2024-11-17 2024-12-31  44 days    Strong
#
# 36.625 352.375
#                date_start   date_end duration  category
# lat    lon
# 36.625 352.375 2024-01-01 2024-03-21  80 days    Strong
#        352.375 2024-04-08 2024-04-27  19 days    Strong
#        352.375 2024-05-29 2024-06-09  11 days  Moderate
#        352.375 2024-11-09 2024-12-31  52 days    Strong
#
# 36.625 352.625
#                date_start   date_end duration  category
# lat    lon
# 36.625 352.625 2024-01-01 2024-03-21  80 days    Strong
#        352.625 2024-04-09 2024-04-27  18 days    Strong
#        352.625 2024-05-29 2024-06-06   8 days  Moderate
#        352.625 2024-11-08 2024-12-31  53 days    Strong
#
# 36.625 352.875
#                date_start   date_end duration  category
# lat    lon
# 36.625 352.875 2024-01-01 2024-03-09  68 days    Strong
#        352.875 2024-03-16 2024-03-21   5 days  Moderate
#        352.875 2024-04-09 2024-04-27  18 days    Strong
#        352.875 2024-05-30 2024-06-03   4 days  Moderate
#        352.875 2024-11-06 2024-12-31  55 days    Strong
#
# 36.625 353.125
#                date_start   date_end duration  category
# lat    lon
# 36.625 353.125 2024-01-01 2024-03-03  62 days    Strong
#        353.125 2024-04-10 2024-04-28  18 days    Strong
#        353.125 2024-08-09 2024-08-13   4 days  Moderate
#        353.125 2024-11-08 2024-12-30  52 days    Strong
#
# 36.625 353.375
#                date_start   date_end duration  category
# lat    lon
# 36.625 353.375 2024-01-17 2024-02-29  43 days    Strong
#        353.375 2024-04-10 2024-04-28  18 days    Strong
#        353.375 2024-08-04 2024-09-04  31 days  Moderate
#        353.375 2024-11-18 2024-12-11  23 days  Moderate
#
# 36.625 353.625
#                date_start   date_end duration  category
# lat    lon
# 36.625 353.625 2024-01-24 2024-02-28  35 days  Moderate
#        353.625 2024-04-10 2024-04-29  19 days    Strong
#        353.625 2024-07-12 2024-07-16   4 days  Moderate
#        353.625 2024-07-22 2024-07-27   5 days  Moderate
#        353.625 2024-08-07 2024-09-04  28 days    Strong
#        353.625 2024-11-29 2024-12-07   8 days  Moderate
#
# 36.875 350.125
#                date_start   date_end duration  category
# lat    lon
# 36.875 350.125 2024-01-01 2024-03-26  85 days    Severe
#        350.125 2024-04-03 2024-05-25  52 days    Strong
#        350.125 2024-06-02 2024-06-06   4 days  Moderate
#        350.125 2024-11-05 2024-11-12   7 days  Moderate
#        350.125 2024-11-19 2024-12-31  42 days    Strong
#
# 36.875 350.375
#                date_start   date_end duration  category
# lat    lon
# 36.875 350.375 2024-01-01 2024-03-20  79 days    Severe
#        350.375 2024-04-03 2024-05-16  43 days    Strong
#        350.375 2024-11-03 2024-11-12   9 days  Moderate
#        350.375 2024-11-19 2024-12-31  42 days    Strong
#
# 36.875 350.625
#                date_start   date_end duration  category
# lat    lon
# 36.875 350.625 2024-01-01 2024-03-03  62 days    Strong
#        350.625 2024-04-03 2024-05-11  38 days  Moderate
#        350.625 2024-11-03 2024-11-12   9 days  Moderate
#        350.625 2024-11-18 2024-12-31  43 days    Strong
#
# 36.875 350.875
#                date_start   date_end duration  category
# lat    lon
# 36.875 350.875 2024-01-01 2024-02-29  59 days    Strong
#        350.875 2024-04-03 2024-04-28  25 days  Moderate
#        350.875 2024-11-18 2024-12-31  43 days    Strong
#
# 36.875 351.125
#                date_start   date_end duration  category
# lat    lon
# 36.875 351.125 2024-01-01 2024-02-29  59 days    Strong
#        351.125 2024-04-08 2024-04-17   9 days  Moderate
#        351.125 2024-04-21 2024-04-27   6 days  Moderate
#        351.125 2024-11-18 2024-12-31  43 days  Moderate
#
# 36.875 351.375
#                date_start   date_end duration  category
# lat    lon
# 36.875 351.375 2024-01-01 2024-02-29  59 days    Strong
#        351.375 2024-04-11 2024-04-27  16 days  Moderate
#        351.375 2024-11-19 2024-12-31  42 days  Moderate
#
# 36.875 351.625
#                date_start   date_end duration  category
# lat    lon
# 36.875 351.625 2024-01-01 2024-03-01  60 days    Strong
#        351.625 2024-04-12 2024-04-27  15 days  Moderate
#        351.625 2024-06-04 2024-06-09   5 days  Moderate
#        351.625 2024-11-23 2024-12-31  38 days  Moderate
#
# 36.875 351.875
#                date_start   date_end duration  category
# lat    lon
# 36.875 351.875 2024-01-01 2024-03-02  61 days    Strong
#        351.875 2024-04-13 2024-04-27  14 days  Moderate
#        351.875 2024-06-03 2024-06-09   6 days  Moderate
#        351.875 2024-11-24 2024-12-31  37 days  Moderate
#
# 36.875 352.125
#                date_start   date_end duration  category
# lat    lon
# 36.875 352.125 2024-01-01 2024-03-03  62 days    Strong
#        352.125 2024-04-11 2024-04-27  16 days    Strong
#        352.125 2024-05-31 2024-06-09   9 days  Moderate
#        352.125 2024-11-23 2024-12-31  38 days    Strong
#
# 36.875 352.375
#                date_start   date_end duration  category
# lat    lon
# 36.875 352.375 2024-01-01 2024-03-02  61 days    Strong
#        352.375 2024-04-10 2024-04-27  17 days    Strong
#        352.375 2024-06-03 2024-06-09   6 days  Moderate
#        352.375 2024-11-22 2024-12-31  39 days    Strong
#
# 36.875 352.625
#                date_start   date_end duration  category
# lat    lon
# 36.875 352.625 2024-01-01 2024-03-02  61 days    Strong
#        352.625 2024-04-10 2024-04-27  17 days    Strong
#        352.625 2024-06-03 2024-06-08   5 days  Moderate
#        352.625 2024-11-17 2024-12-31  44 days    Strong
#
# 36.875 352.875
#                date_start   date_end duration category
# lat    lon
# 36.875 352.875 2024-01-01 2024-03-01  60 days   Strong
#        352.875 2024-04-10 2024-04-27  17 days   Strong
#        352.875 2024-11-18 2024-12-31  43 days   Strong
#
# 36.875 353.125
#                date_start   date_end duration  category
# lat    lon
# 36.875 353.125 2024-01-01 2024-02-28  58 days    Strong
#        353.125 2024-04-10 2024-04-28  18 days    Strong
#        353.125 2024-08-04 2024-09-02  29 days  Moderate
#        353.125 2024-11-19 2024-12-12  23 days  Moderate
#
# 36.875 353.375
#                date_start   date_end duration  category
# lat    lon
# 36.875 353.375 2024-01-17 2024-02-28  42 days  Moderate
#        353.375 2024-04-10 2024-04-28  18 days    Strong
#        353.375 2024-07-10 2024-07-14   4 days  Moderate
#        353.375 2024-07-26 2024-09-04  40 days    Strong
#        353.375 2024-11-23 2024-12-09  16 days  Moderate
#
# 37.125 350.125
#                date_start   date_end duration  category
# lat    lon
# 37.125 350.125 2024-01-01 2024-03-24  83 days    Severe
#        350.125 2024-04-03 2024-05-17  44 days    Strong
#        350.125 2024-11-05 2024-11-11   6 days  Moderate
#        350.125 2024-11-21 2024-12-31  40 days    Strong
#
# 37.125 350.375
#                date_start   date_end duration  category
# lat    lon
# 37.125 350.375 2024-01-01 2024-03-04  63 days    Strong
#        350.375 2024-03-12 2024-03-20   8 days  Moderate
#        350.375 2024-04-03 2024-05-12  39 days  Moderate
#        350.375 2024-11-02 2024-11-11   9 days  Moderate
#        350.375 2024-11-19 2024-12-31  42 days    Strong
#
# 37.125 350.625
#                date_start   date_end duration  category
# lat    lon
# 37.125 350.625 2024-01-01 2024-03-02  61 days    Strong
#        350.625 2024-04-03 2024-04-27  24 days  Moderate
#        350.625 2024-05-03 2024-05-11   8 days  Moderate
#        350.625 2024-11-04 2024-11-09   5 days  Moderate
#        350.625 2024-11-19 2024-12-31  42 days    Strong
#
# 37.125 350.875
#                date_start   date_end duration  category
# lat    lon
# 37.125 350.875 2024-01-01 2024-02-29  59 days    Strong
#        350.875 2024-04-06 2024-04-17  11 days  Moderate
#        350.875 2024-04-21 2024-04-26   5 days  Moderate
#        350.875 2024-11-19 2024-12-31  42 days  Moderate
#
# 37.125 351.125
#                date_start   date_end duration  category
# lat    lon
# 37.125 351.125 2024-01-01 2024-02-28  58 days    Strong
#        351.125 2024-04-21 2024-04-26   5 days  Moderate
#        351.125 2024-11-21 2024-12-31  40 days  Moderate
#
# 37.125 351.375
#                date_start   date_end duration  category
# lat    lon
# 37.125 351.375 2024-01-01 2024-02-28  58 days    Strong
#        351.375 2024-04-21 2024-04-27   6 days  Moderate
#        351.375 2024-11-24 2024-12-31  37 days  Moderate
#
# 37.125 351.625
#                date_start   date_end duration  category
# lat    lon
# 37.125 351.625 2024-01-01 2024-02-28  58 days    Strong
#        351.625 2024-04-14 2024-04-27  13 days  Moderate
#        351.625 2024-11-30 2024-12-31  31 days  Moderate
#
# 37.125 351.875
#                date_start   date_end duration  category
# lat    lon
# 37.125 351.875 2024-01-01 2024-02-28  58 days    Strong
#        351.875 2024-04-14 2024-04-27  13 days  Moderate
#        351.875 2024-11-30 2024-12-31  31 days  Moderate
#
# 37.125 352.375
#                date_start   date_end duration  category
# lat    lon
# 37.125 352.375 2024-01-01 2024-02-28  58 days    Strong
#        352.375 2024-04-11 2024-04-27  16 days    Strong
#        352.375 2024-06-04 2024-06-08   4 days  Moderate
#        352.375 2024-11-29 2024-12-29  30 days  Moderate
#
# 37.125 352.625
#                date_start   date_end duration  category
# lat    lon
# 37.125 352.625 2024-01-01 2024-02-28  58 days    Strong
#        352.625 2024-04-11 2024-04-27  16 days    Strong
#        352.625 2024-06-04 2024-06-08   4 days  Moderate
#        352.625 2024-11-29 2024-12-29  30 days  Moderate
#
# 37.125 352.875
#                date_start   date_end duration  category
# lat    lon
# 37.125 352.875 2024-01-01 2024-02-27  57 days    Strong
#        352.875 2024-04-12 2024-04-27  15 days    Strong
#        352.875 2024-06-03 2024-06-07   4 days  Moderate
#        352.875 2024-08-07 2024-08-13   6 days  Moderate
#        352.875 2024-08-23 2024-09-02  10 days  Moderate
#        352.875 2024-11-24 2024-12-19  25 days  Moderate
#        352.875 2024-12-23 2024-12-28   5 days  Moderate
#
# 37.125 353.125
#                date_start   date_end duration  category
# lat    lon
# 37.125 353.125 2024-01-01 2024-01-06   5 days  Moderate
#        353.125 2024-01-18 2024-02-26  39 days    Strong
#        353.125 2024-04-12 2024-04-28  16 days    Strong
#        353.125 2024-07-28 2024-09-03  37 days    Strong
#        353.125 2024-11-29 2024-12-09  10 days  Moderate
#
# 37.375 350.125
#                date_start   date_end duration  category
# lat    lon
# 37.375 350.125 2024-01-01 2024-03-24  83 days    Strong
#        350.125 2024-04-06 2024-05-13  37 days    Strong
#        350.125 2024-10-13 2024-10-28  15 days  Moderate
#        350.125 2024-11-06 2024-11-11   5 days  Moderate
#        350.125 2024-11-21 2024-12-31  40 days    Strong
#
# 37.375 350.375
#                date_start   date_end duration  category
# lat    lon
# 37.375 350.375 2024-01-01 2024-03-21  80 days    Strong
#        350.375 2024-04-06 2024-04-27  21 days  Moderate
#        350.375 2024-05-03 2024-05-11   8 days  Moderate
#        350.375 2024-10-11 2024-11-11  31 days  Moderate
#        350.375 2024-11-21 2024-12-31  40 days    Strong
#
# 37.375 350.625
#                date_start   date_end duration  category
# lat    lon
# 37.375 350.625 2024-01-01 2024-03-03  62 days    Strong
#        350.625 2024-04-06 2024-04-26  20 days  Moderate
#        350.625 2024-10-13 2024-10-20   7 days  Moderate
#        350.625 2024-11-02 2024-11-10   8 days  Moderate
#        350.625 2024-11-20 2024-12-31  41 days  Moderate
#
# 37.375 350.875
#                date_start   date_end duration  category
# lat    lon
# 37.375 350.875 2024-01-01 2024-02-29  59 days    Strong
#        350.875 2024-04-12 2024-04-26  14 days  Moderate
#        350.875 2024-11-05 2024-11-09   4 days  Moderate
#        350.875 2024-11-21 2024-12-31  40 days  Moderate
#
# 37.375 351.125
#                date_start   date_end duration  category
# lat    lon
# 37.375 351.125 2024-01-01 2024-02-28  58 days    Strong
#        351.125 2024-04-13 2024-04-25  12 days  Moderate
#        351.125 2024-11-22 2024-12-31  39 days  Moderate
#
# 37.625 350.125
#                date_start   date_end duration  category
# lat    lon
# 37.625 350.125 2024-01-01 2024-03-08  67 days    Strong
#        350.125 2024-03-12 2024-03-24  12 days  Moderate
#        350.125 2024-04-06 2024-04-29  23 days    Strong
#        350.125 2024-05-03 2024-05-11   8 days  Moderate
#        350.125 2024-10-07 2024-10-28  21 days  Moderate
#        350.125 2024-11-21 2024-12-31  40 days  Moderate
#
# 37.625 350.375
#                date_start   date_end duration  category
# lat    lon
# 37.625 350.375 2024-01-01 2024-03-08  67 days    Strong
#        350.375 2024-03-12 2024-03-21   9 days  Moderate
#        350.375 2024-04-06 2024-04-28  22 days    Strong
#        350.375 2024-05-03 2024-05-11   8 days  Moderate
#        350.375 2024-10-07 2024-11-12  36 days  Moderate
#        350.375 2024-11-21 2024-12-31  40 days  Moderate
#
# 37.625 350.625
#                date_start   date_end duration  category
# lat    lon
# 37.625 350.625 2024-01-01 2024-03-06  65 days    Strong
#        350.625 2024-04-08 2024-04-27  19 days  Moderate
#        350.625 2024-10-11 2024-11-12  32 days  Moderate
#        350.625 2024-11-20 2024-12-31  41 days  Moderate
#
# 37.625 350.875
#                date_start   date_end duration  category
# lat    lon
# 37.625 350.875 2024-01-01 2024-03-02  61 days    Strong
#        350.875 2024-04-12 2024-04-26  14 days  Moderate
#        350.875 2024-10-14 2024-10-26  12 days  Moderate
#        350.875 2024-11-01 2024-11-11  10 days  Moderate
#        350.875 2024-11-21 2024-12-31  40 days  Moderate
#
# 37.625 351.125
#                date_start   date_end duration  category
# lat    lon
# 37.625 351.125 2024-01-01 2024-02-29  59 days    Strong
#        351.125 2024-04-12 2024-04-25  13 days  Moderate
#        351.125 2024-11-04 2024-11-10   6 days  Moderate
#        351.125 2024-11-22 2024-12-12  20 days  Moderate
#
# 37.875 350.125
#                date_start   date_end duration  category
# lat    lon
# 37.875 350.125 2024-01-01 2024-03-06  65 days    Strong
#        350.125 2024-03-13 2024-03-21   8 days  Moderate
#        350.125 2024-04-09 2024-05-11  32 days    Strong
#        350.125 2024-05-20 2024-05-24   4 days  Moderate
#        350.125 2024-10-06 2024-10-26  20 days  Moderate
#        350.125 2024-11-18 2024-12-31  43 days  Moderate
#
# 37.875 350.375
#                date_start   date_end duration  category
# lat    lon
# 37.875 350.375 2024-01-01 2024-03-06  65 days    Strong
#        350.375 2024-04-09 2024-04-29  20 days    Strong
#        350.375 2024-05-03 2024-05-11   8 days  Moderate
#        350.375 2024-10-07 2024-10-28  21 days  Moderate
#        350.375 2024-11-09 2024-11-13   4 days  Moderate
#        350.375 2024-11-18 2024-12-31  43 days  Moderate
#
# 37.875 350.625
#                date_start   date_end duration  category
# lat    lon
# 37.875 350.625 2024-01-01 2024-03-04  63 days    Strong
#        350.625 2024-04-10 2024-04-28  18 days    Strong
#        350.625 2024-10-12 2024-11-13  32 days  Moderate
#        350.625 2024-11-19 2024-12-31  42 days  Moderate
#
# 37.875 350.875
#                date_start   date_end duration  category
# lat    lon
# 37.875 350.875 2024-01-01 2024-03-02  61 days    Strong
#        350.875 2024-04-12 2024-04-27  15 days  Moderate
#        350.875 2024-10-16 2024-10-29  13 days  Moderate
#        350.875 2024-11-04 2024-11-12   8 days  Moderate
#        350.875 2024-11-24 2024-12-20  26 days  Moderate
#
# 37.875 351.125
#                date_start   date_end duration  category
# lat    lon
# 37.875 351.125 2024-01-01 2024-02-29  59 days    Strong
#        351.125 2024-04-12 2024-04-27  15 days  Moderate
#        351.125 2024-10-20 2024-10-26   6 days  Moderate
#        351.125 2024-11-04 2024-11-11   7 days  Moderate
#        351.125 2024-11-26 2024-12-10  14 days  Moderate
#
# 38.125 350.125
#                date_start   date_end duration  category
# lat    lon
# 38.125 350.125 2024-01-01 2024-03-04  63 days    Strong
#        350.125 2024-03-18 2024-03-24   6 days  Moderate
#        350.125 2024-04-12 2024-04-29  17 days    Strong
#        350.125 2024-05-03 2024-05-11   8 days  Moderate
#        350.125 2024-09-21 2024-10-24  33 days  Moderate
#        350.125 2024-11-17 2024-12-31  44 days  Moderate
#
# 38.125 350.375
#                date_start   date_end duration  category
# lat    lon
# 38.125 350.375 2024-01-01 2024-03-04  63 days    Strong
#        350.375 2024-04-12 2024-04-28  16 days    Strong
#        350.375 2024-09-21 2024-09-26   5 days  Moderate
#        350.375 2024-10-07 2024-10-25  18 days  Moderate
#        350.375 2024-11-18 2024-12-31  43 days  Moderate
#
# 38.125 350.625
#                date_start   date_end duration  category
# lat    lon
# 38.125 350.625 2024-01-01 2024-03-03  62 days    Strong
#        350.625 2024-04-12 2024-04-28  16 days    Strong
#        350.625 2024-10-19 2024-10-25   6 days  Moderate
#        350.625 2024-11-09 2024-11-13   4 days  Moderate
#        350.625 2024-11-24 2024-12-28  34 days  Moderate
#
# 38.125 350.875
#                date_start   date_end duration  category
# lat    lon
# 38.125 350.875 2024-01-01 2024-03-01  60 days    Strong
#        350.875 2024-04-12 2024-04-28  16 days    Strong
#        350.875 2024-10-20 2024-10-26   6 days  Moderate
#        350.875 2024-11-08 2024-11-12   4 days  Moderate
#        350.875 2024-11-29 2024-12-11  12 days  Moderate
#
# 38.125 351.125
#                date_start   date_end duration  category
# lat    lon
# 38.125 351.125 2024-01-01 2024-02-28  58 days    Strong
#        351.125 2024-04-11 2024-04-28  17 days    Strong
#        351.125 2024-10-22 2024-10-26   4 days  Moderate
#        351.125 2024-12-01 2024-12-09   8 days  Moderate
#
# 38.375 350.125
#                date_start   date_end duration  category
# lat    lon
# 38.375 350.125 2024-01-01 2024-03-03  62 days    Strong
#        350.125 2024-04-12 2024-04-27  15 days  Moderate
#        350.125 2024-09-23 2024-09-27   4 days  Moderate
#        350.125 2024-10-06 2024-10-21  15 days  Moderate
#        350.125 2024-11-18 2024-12-31  43 days  Moderate
#
# 38.375 350.375
#                date_start   date_end duration  category
# lat    lon
# 38.375 350.375 2024-01-01 2024-03-02  61 days    Strong
#        350.375 2024-04-12 2024-04-27  15 days  Moderate
#        350.375 2024-10-10 2024-10-14   4 days  Moderate
#        350.375 2024-11-18 2024-12-31  43 days  Moderate
#
# 38.375 350.625
#                date_start   date_end duration  category
# lat    lon
# 38.375 350.625 2024-01-01 2024-03-01  60 days    Strong
#        350.625 2024-04-12 2024-04-28  16 days  Moderate
#        350.625 2024-11-26 2024-12-10  14 days  Moderate
#        350.625 2024-12-21 2024-12-28   7 days  Moderate
#
# 38.375 350.875
#                date_start   date_end duration  category
# lat    lon
# 38.375 350.875 2024-01-01 2024-02-29  59 days    Strong
#        350.875 2024-04-12 2024-04-29  17 days    Strong
#        350.875 2024-12-01 2024-12-09   8 days  Moderate
#
# 38.375 351.125
#                date_start   date_end duration  category
# lat    lon
# 38.375 351.125 2024-01-12 2024-02-27  46 days  Moderate
#        351.125 2024-04-11 2024-04-29  18 days    Strong
#        351.125 2024-12-03 2024-12-08   5 days  Moderate
#
# 38.625 350.125
#                date_start   date_end duration  category
# lat    lon
# 38.625 350.125 2024-01-01 2024-03-02  61 days    Strong
#        350.125 2024-04-12 2024-04-27  15 days  Moderate
#        350.125 2024-10-07 2024-10-21  14 days  Moderate
#        350.125 2024-11-20 2024-12-31  41 days  Moderate
#
# 38.625 350.375
#                date_start   date_end duration  category
# lat    lon
# 38.625 350.375 2024-01-01 2024-03-02  61 days    Strong
#        350.375 2024-04-12 2024-04-27  15 days  Moderate
#        350.375 2024-11-20 2024-12-31  41 days  Moderate
#
# 38.625 350.625
#                date_start   date_end duration  category
# lat    lon
# 38.625 350.625 2024-01-01 2024-03-01  60 days    Strong
#        350.625 2024-04-12 2024-04-27  15 days  Moderate
#        350.625 2024-11-24 2024-12-09  15 days  Moderate
#        350.625 2024-12-23 2024-12-30   7 days  Moderate
#
# 38.875 350.125
#                date_start   date_end duration  category
# lat    lon
# 38.875 350.125 2024-01-01 2024-03-02  61 days    Strong
#        350.125 2024-04-12 2024-04-27  15 days  Moderate
#        350.125 2024-10-13 2024-10-25  12 days  Moderate
#        350.125 2024-11-20 2024-12-31  41 days  Moderate
#
# 38.875 350.375
#                date_start   date_end duration  category
# lat    lon
# 38.875 350.375 2024-01-01 2024-03-01  60 days    Strong
#        350.375 2024-04-12 2024-04-26  14 days  Moderate
#        350.375 2024-11-21 2024-12-10  19 days  Moderate
#        350.375 2024-12-14 2024-12-31  17 days  Moderate
#
# 39.125 350.125
#                date_start   date_end duration  category
# lat    lon
# 39.125 350.125 2024-01-01 2024-03-03  62 days    Strong
#        350.125 2024-04-11 2024-04-27  16 days  Moderate
#        350.125 2024-10-13 2024-10-26  13 days  Moderate
#        350.125 2024-11-08 2024-11-12   4 days  Moderate
#        350.125 2024-11-20 2024-12-31  41 days  Moderate
#
# 39.125 350.375
#                date_start   date_end duration  category
# lat    lon
# 39.125 350.375 2024-01-16 2024-03-01  45 days    Strong
#        350.375 2024-04-12 2024-04-25  13 days  Moderate
#        350.375 2024-11-23 2024-12-11  18 days  Moderate
#        350.375 2024-12-26 2024-12-31   5 days  Moderate
#
# 39.125 350.625
#                date_start   date_end duration  category
# lat    lon
# 39.125 350.625 2024-01-18 2024-03-01  43 days    Strong
#        350.625 2024-04-12 2024-04-25  13 days  Moderate
#        350.625 2024-11-25 2024-12-09  14 days  Moderate
#
# 39.375 350.125
#                date_start   date_end duration  category
# lat    lon
# 39.375 350.125 2024-01-01 2024-03-03  62 days    Strong
#        350.125 2024-04-11 2024-04-27  16 days    Strong
#        350.125 2024-05-07 2024-05-13   6 days  Moderate
#        350.125 2024-06-03 2024-06-09   6 days  Moderate
#        350.125 2024-10-13 2024-10-26  13 days  Moderate
#        350.125 2024-11-06 2024-11-13   7 days  Moderate
#        350.125 2024-11-20 2024-12-31  41 days    Strong
#
# 39.375 350.375
#                date_start   date_end duration  category
# lat    lon
# 39.375 350.375 2024-01-17 2024-03-02  45 days    Strong
#        350.375 2024-04-12 2024-04-27  15 days  Moderate
#        350.375 2024-10-17 2024-10-21   4 days  Moderate
#        350.375 2024-11-08 2024-11-12   4 days  Moderate
#        350.375 2024-11-21 2024-12-31  40 days  Moderate
#
# 39.375 350.625
#                date_start   date_end duration  category
# lat    lon
# 39.375 350.625 2024-01-17 2024-03-01  44 days    Strong
#        350.625 2024-04-12 2024-04-25  13 days  Moderate
#        350.625 2024-11-22 2024-12-10  18 days  Moderate
#
# 39.625 350.125
#                date_start   date_end duration  category
# lat    lon
# 39.625 350.125 2024-01-01 2024-03-03  62 days    Strong
#        350.125 2024-04-09 2024-04-28  19 days    Strong
#        350.125 2024-05-07 2024-05-13   6 days  Moderate
#        350.125 2024-06-03 2024-06-09   6 days  Moderate
#        350.125 2024-07-20 2024-07-24   4 days  Moderate
#        350.125 2024-10-12 2024-10-26  14 days  Moderate
#        350.125 2024-11-02 2024-11-14  12 days  Moderate
#        350.125 2024-11-18 2024-12-31  43 days    Strong
#
# 39.625 350.375
#                date_start   date_end duration  category
# lat    lon
# 39.625 350.375 2024-01-02 2024-03-02  60 days    Strong
#        350.375 2024-04-12 2024-04-27  15 days    Strong
#        350.375 2024-10-13 2024-10-25  12 days  Moderate
#        350.375 2024-11-06 2024-11-13   7 days  Moderate
#        350.375 2024-11-20 2024-12-31  41 days  Moderate
#
# 39.625 350.625
#                date_start   date_end duration  category
# lat    lon
# 39.625 350.625 2024-01-17 2024-03-02  45 days    Strong
#        350.625 2024-04-12 2024-04-27  15 days  Moderate
#        350.625 2024-11-22 2024-12-16  24 days  Moderate
#
# 39.625 350.875
#                date_start   date_end duration  category
# lat    lon
# 39.625 350.875 2024-01-18 2024-03-02  44 days    Strong
#        350.875 2024-04-12 2024-04-26  14 days  Moderate
#        350.875 2024-11-25 2024-12-10  15 days  Moderate
#
# 39.875 350.125
#                date_start   date_end duration  category
# lat    lon
# 39.875 350.125 2024-01-01 2024-03-03  62 days    Strong
#        350.125 2024-04-12 2024-04-28  16 days    Strong
#        350.125 2024-05-08 2024-05-13   5 days  Moderate
#        350.125 2024-06-03 2024-06-09   6 days  Moderate
#        350.125 2024-07-20 2024-07-24   4 days  Moderate
#        350.125 2024-10-13 2024-12-31  79 days    Strong
#
# 39.875 350.375
#                date_start   date_end duration  category
# lat    lon
# 39.875 350.375 2024-01-01 2024-03-03  62 days    Strong
#        350.375 2024-03-13 2024-03-21   8 days  Moderate
#        350.375 2024-04-12 2024-04-27  15 days    Strong
#        350.375 2024-10-13 2024-10-25  12 days  Moderate
#        350.375 2024-11-04 2024-11-13   9 days  Moderate
#        350.375 2024-11-21 2024-12-31  40 days  Moderate
#
# 39.875 350.625
#                date_start   date_end duration  category
# lat    lon
# 39.875 350.625 2024-01-16 2024-03-02  46 days    Strong
#        350.625 2024-03-13 2024-03-21   8 days  Moderate
#        350.625 2024-04-12 2024-04-27  15 days  Moderate
#        350.625 2024-10-18 2024-10-24   6 days  Moderate
#        350.625 2024-11-08 2024-11-12   4 days  Moderate
#        350.625 2024-11-22 2024-12-24  32 days  Moderate
#
# 39.875 350.875
#                date_start   date_end duration  category
# lat    lon
# 39.875 350.875 2024-01-18 2024-03-02  44 days    Strong
#        350.875 2024-03-13 2024-03-21   8 days  Moderate
#        350.875 2024-04-12 2024-04-26  14 days  Moderate
#        350.875 2024-11-26 2024-12-10  14 days  Moderate
#
# 40.125 350.125
#                date_start   date_end duration  category
# lat    lon
# 40.125 350.125 2024-01-01 2024-03-03  62 days    Strong
#        350.125 2024-04-12 2024-04-28  16 days    Strong
#        350.125 2024-10-14 2024-12-31  78 days  Moderate
#
# 40.125 350.375
#                date_start   date_end duration  category
# lat    lon
# 40.125 350.375 2024-01-01 2024-03-03  62 days    Strong
#        350.375 2024-03-13 2024-03-21   8 days  Moderate
#        350.375 2024-04-12 2024-04-27  15 days    Strong
#        350.375 2024-10-14 2024-10-26  12 days  Moderate
#        350.375 2024-11-01 2024-11-14  13 days  Moderate
#        350.375 2024-11-20 2024-12-31  41 days  Moderate
#
# 40.125 350.625
#                date_start   date_end duration  category
# lat    lon
# 40.125 350.625 2024-01-02 2024-03-02  60 days    Strong
#        350.625 2024-03-13 2024-03-21   8 days  Moderate
#        350.625 2024-04-12 2024-04-27  15 days  Moderate
#        350.625 2024-10-17 2024-10-24   7 days  Moderate
#        350.625 2024-11-08 2024-11-12   4 days  Moderate
#        350.625 2024-11-22 2024-12-28  36 days  Moderate
#
# 40.125 350.875
#                date_start   date_end duration  category
# lat    lon
# 40.125 350.875 2024-01-19 2024-03-02  43 days    Strong
#        350.875 2024-03-15 2024-03-21   6 days  Moderate
#        350.875 2024-04-12 2024-04-26  14 days  Moderate
#        350.875 2024-10-19 2024-10-24   5 days  Moderate
#        350.875 2024-11-26 2024-12-10  14 days  Moderate
#
# 40.125 351.125
#                date_start   date_end duration  category
# lat    lon
# 40.125 351.125 2024-01-31 2024-03-02  31 days    Strong
#        351.125 2024-03-15 2024-03-21   6 days  Moderate
#        351.125 2024-04-12 2024-04-23  11 days  Moderate
#        351.125 2024-10-19 2024-10-24   5 days  Moderate
# ...
#        350.875 2024-03-15 2024-03-22   7 days  Moderate
#        350.875 2024-04-12 2024-04-26  14 days  Moderate
#        350.875 2024-10-19 2024-10-24   5 days  Moderate
#        350.875 2024-11-27 2024-12-10  13 days  Moderate
#
# 40.375 351.125
#                date_start   date_end duration  category
# lat    lon
# 40.375 351.125 2024-01-31 2024-03-02  31 days    Strong
#        351.125 2024-03-15 2024-03-21   6 days  Moderate
#        351.125 2024-04-12 2024-04-23  11 days  Moderate
#        351.125 2024-10-19 2024-10-24   5 days  Moderate
#        351.125 2024-12-01 2024-12-08   7 days  Moderate
#
# 40.625 350.125
#                date_start   date_end duration category
# lat    lon
# 40.625 350.125 2024-01-01 2024-03-03  62 days   Strong
#        350.125 2024-04-12 2024-04-27  15 days   Strong
#        350.125 2024-05-08 2024-05-12   4 days   Strong
#        350.125 2024-10-15 2024-12-31  77 days   Strong
#
# 40.625 350.375
#                date_start   date_end duration  category
# lat    lon
# 40.625 350.375 2024-01-01 2024-03-03  62 days    Strong
#        350.375 2024-03-12 2024-03-20   8 days  Moderate
#        350.375 2024-04-12 2024-04-27  15 days    Strong
#        350.375 2024-10-17 2024-10-26   9 days  Moderate
#        350.375 2024-10-31 2024-12-31  61 days    Strong
#
# 40.625 350.625
#                date_start   date_end duration  category
# lat    lon
# 40.625 350.625 2024-01-02 2024-03-03  61 days    Strong
#        350.625 2024-03-13 2024-03-21   8 days  Moderate
#        350.625 2024-04-12 2024-04-26  14 days  Moderate
#        350.625 2024-10-20 2024-10-24   4 days  Moderate
#        350.625 2024-11-01 2024-11-13  12 days  Moderate
#        350.625 2024-11-20 2024-12-31  41 days  Moderate
#
# 40.625 350.875
#                date_start   date_end duration  category
# lat    lon
# 40.625 350.875 2024-01-17 2024-03-02  45 days    Strong
#        350.875 2024-03-15 2024-03-21   6 days  Moderate
#        350.875 2024-04-12 2024-04-24  12 days  Moderate
#        350.875 2024-10-19 2024-10-24   5 days  Moderate
#        350.875 2024-11-04 2024-11-12   8 days  Moderate
#        350.875 2024-11-23 2024-12-27  34 days  Moderate
#
# 40.625 351.125
#                date_start   date_end duration  category
# lat    lon
# 40.625 351.125 2024-01-31 2024-03-02  31 days    Strong
#        351.125 2024-03-15 2024-03-21   6 days  Moderate
#        351.125 2024-04-12 2024-04-23  11 days  Moderate
#        351.125 2024-10-14 2024-10-25  11 days  Moderate
#        351.125 2024-11-30 2024-12-09   9 days  Moderate
#
# 40.875 350.125
#                date_start   date_end duration  category
# lat    lon
# 40.875 350.125 2024-01-01 2024-03-03  62 days    Strong
#        350.125 2024-03-12 2024-03-20   8 days  Moderate
#        350.125 2024-04-12 2024-04-27  15 days    Strong
#        350.125 2024-05-08 2024-05-13   5 days    Strong
#        350.125 2024-10-19 2024-10-25   6 days  Moderate
#        350.125 2024-11-01 2024-12-31  60 days    Strong
#
# 40.875 350.375
#                date_start   date_end duration  category
# lat    lon
# 40.875 350.375 2024-01-01 2024-03-03  62 days    Strong
#        350.375 2024-03-12 2024-03-20   8 days  Moderate
#        350.375 2024-04-12 2024-04-26  14 days    Strong
#        350.375 2024-05-08 2024-05-12   4 days  Moderate
#        350.375 2024-11-01 2024-12-31  60 days    Strong
#
# 40.875 350.625
#                date_start   date_end duration  category
# lat    lon
# 40.875 350.625 2024-01-02 2024-03-03  61 days    Strong
#        350.625 2024-03-13 2024-03-20   7 days  Moderate
#        350.625 2024-04-12 2024-04-24  12 days  Moderate
#        350.625 2024-11-01 2024-12-31  60 days  Moderate
#
# 40.875 350.875
#                date_start   date_end duration  category
# lat    lon
# 40.875 350.875 2024-01-17 2024-03-02  45 days    Strong
#        350.875 2024-03-13 2024-03-21   8 days  Moderate
#        350.875 2024-04-12 2024-04-24  12 days  Moderate
#        350.875 2024-10-14 2024-10-24  10 days  Moderate
#        350.875 2024-11-01 2024-11-13  12 days  Moderate
#        350.875 2024-11-23 2024-12-30  37 days  Moderate
#
# 40.875 351.125
#                date_start   date_end duration  category
# lat    lon
# 40.875 351.125 2024-01-22 2024-01-26   4 days  Moderate
#        351.125 2024-01-30 2024-03-02  32 days    Strong
#        351.125 2024-03-15 2024-03-21   6 days  Moderate
#        351.125 2024-04-12 2024-04-23  11 days  Moderate
#        351.125 2024-10-14 2024-10-25  11 days  Moderate
#        351.125 2024-11-02 2024-11-09   7 days  Moderate
#        351.125 2024-11-30 2024-12-09   9 days  Moderate
#
# 41.125 350.125
#                date_start   date_end duration category
# lat    lon
# 41.125 350.125 2024-01-01 2024-03-20  79 days   Strong
#        350.125 2024-04-12 2024-04-26  14 days   Strong
#        350.125 2024-05-08 2024-05-13   5 days   Strong
#        350.125 2024-11-06 2024-12-31  55 days   Strong
#
# 41.125 350.375
#                date_start   date_end duration  category
# lat    lon
# 41.125 350.375 2024-01-01 2024-03-08  67 days    Strong
#        350.375 2024-03-12 2024-03-20   8 days  Moderate
#        350.375 2024-04-12 2024-04-26  14 days    Strong
#        350.375 2024-05-08 2024-05-13   5 days  Moderate
#        350.375 2024-11-06 2024-12-31  55 days    Strong
#
# 41.125 350.625
#                date_start   date_end duration  category
# lat    lon
# 41.125 350.625 2024-01-06 2024-03-03  57 days    Strong
#        350.625 2024-03-13 2024-03-20   7 days  Moderate
#        350.625 2024-04-12 2024-04-24  12 days  Moderate
#        350.625 2024-11-04 2024-12-31  57 days  Moderate
#
# 41.125 350.875
#                date_start   date_end duration  category
# lat    lon
# 41.125 350.875 2024-01-18 2024-03-02  44 days    Strong
#        350.875 2024-03-13 2024-03-20   7 days  Moderate
#        350.875 2024-04-12 2024-04-24  12 days  Moderate
#        350.875 2024-10-14 2024-10-24  10 days  Moderate
#        350.875 2024-11-03 2024-11-13  10 days  Moderate
#        350.875 2024-11-23 2024-12-31  38 days  Moderate
#
# 41.125 351.125
#                date_start   date_end duration  category
# lat    lon
# 41.125 351.125 2024-02-08 2024-03-02  23 days    Strong
#        351.125 2024-03-13 2024-03-20   7 days  Moderate
#        351.125 2024-04-12 2024-04-16   4 days  Moderate
#        351.125 2024-10-13 2024-10-25  12 days  Moderate
#        351.125 2024-11-03 2024-11-12   9 days  Moderate
#        351.125 2024-12-01 2024-12-09   8 days  Moderate
#
# 41.125 351.375
#                date_start   date_end duration  category
# lat    lon
# 41.125 351.375 2024-02-11 2024-03-02  20 days  Moderate
#        351.375 2024-03-15 2024-03-20   5 days  Moderate
#        351.375 2024-10-13 2024-10-26  13 days  Moderate
#        351.375 2024-11-03 2024-11-09   6 days  Moderate
#
# 41.375 350.125
#                date_start   date_end duration  category
# lat    lon
# 41.375 350.125 2024-01-01 2024-03-20  79 days    Strong
#        350.125 2024-04-12 2024-04-26  14 days    Strong
#        350.125 2024-05-08 2024-05-13   5 days  Moderate
#        350.125 2024-07-29 2024-08-04   6 days  Moderate
#        350.125 2024-11-09 2024-12-31  52 days    Strong
#
# 41.375 350.375
#                date_start   date_end duration  category
# lat    lon
# 41.375 350.375 2024-01-01 2024-03-20  79 days    Strong
#        350.375 2024-04-12 2024-04-25  13 days    Strong
#        350.375 2024-05-08 2024-05-13   5 days  Moderate
#        350.375 2024-11-08 2024-12-31  53 days    Strong
#
# 41.375 350.625
#                date_start   date_end duration  category
# lat    lon
# 41.375 350.625 2024-01-07 2024-03-05  58 days    Strong
#        350.625 2024-03-12 2024-03-20   8 days  Moderate
#        350.625 2024-04-12 2024-04-24  12 days  Moderate
#        350.625 2024-10-14 2024-10-21   7 days  Moderate
#        350.625 2024-11-08 2024-12-31  53 days    Strong
#
# 41.375 350.875
#                date_start   date_end duration  category
# lat    lon
# 41.375 350.875 2024-01-18 2024-03-03  45 days    Strong
#        350.875 2024-03-13 2024-03-20   7 days  Moderate
#        350.875 2024-04-12 2024-04-16   4 days  Moderate
#        350.875 2024-04-20 2024-04-24   4 days  Moderate
#        350.875 2024-10-13 2024-10-24  11 days  Moderate
#        350.875 2024-11-04 2024-11-13   9 days  Moderate
#        350.875 2024-11-21 2024-12-31  40 days  Moderate
#
# 41.375 351.125
#                date_start   date_end duration  category
# lat    lon
# 41.375 351.125 2024-01-30 2024-02-03   4 days  Moderate
#        351.125 2024-02-08 2024-03-02  23 days    Strong
#        351.125 2024-03-13 2024-03-20   7 days  Moderate
#        351.125 2024-10-13 2024-10-25  12 days  Moderate
#        351.125 2024-11-04 2024-11-13   9 days  Moderate
#        351.125 2024-11-27 2024-12-10  13 days  Moderate
#
# 41.625 350.125
#                date_start   date_end duration  category
# lat    lon
# 41.625 350.125 2024-01-01 2024-03-08  67 days    Strong
#        350.125 2024-04-12 2024-04-25  13 days    Strong
#        350.125 2024-05-08 2024-05-13   5 days  Moderate
#        350.125 2024-07-29 2024-08-07   9 days  Moderate
#        350.125 2024-11-19 2024-12-31  42 days    Strong
#
# 41.625 350.375
#                date_start   date_end duration  category
# lat    lon
# 41.625 350.375 2024-01-01 2024-03-14  73 days    Strong
#        350.375 2024-04-12 2024-04-24  12 days    Strong
#        350.375 2024-05-08 2024-05-12   4 days  Moderate
#        350.375 2024-07-30 2024-08-03   4 days  Moderate
#        350.375 2024-11-09 2024-11-13   4 days  Moderate
#        350.375 2024-11-17 2024-12-31  44 days    Strong
#
# 41.625 350.625
#                date_start   date_end duration  category
# lat    lon
# 41.625 350.625 2024-01-02 2024-01-11   9 days  Moderate
#        350.625 2024-01-16 2024-03-07  51 days    Strong
#        350.625 2024-04-12 2024-04-24  12 days  Moderate
#        350.625 2024-10-14 2024-10-23   9 days  Moderate
#        350.625 2024-11-09 2024-11-13   4 days  Moderate
#        350.625 2024-11-18 2024-12-31  43 days    Strong
#
# 41.625 350.875
#                date_start   date_end duration  category
# lat    lon
# 41.625 350.875 2024-01-18 2024-03-03  45 days    Strong
#        350.875 2024-04-12 2024-04-16   4 days  Moderate
#        350.875 2024-10-13 2024-10-24  11 days  Moderate
#        350.875 2024-11-08 2024-11-13   5 days  Moderate
#        350.875 2024-11-21 2024-12-31  40 days  Moderate
#
# 41.625 351.125
#                date_start   date_end duration  category
# lat    lon
# 41.625 351.125 2024-02-08 2024-03-02  23 days  Moderate
#        351.125 2024-10-13 2024-10-24  11 days  Moderate
#        351.125 2024-11-08 2024-11-12   4 days  Moderate
#        351.125 2024-11-28 2024-12-10  12 days  Moderate
#
# 41.875 350.125
#                date_start   date_end duration  category
# lat    lon
# 41.875 350.125 2024-01-01 2024-03-07  66 days    Strong
#        350.125 2024-04-12 2024-04-25  13 days    Strong
#        350.125 2024-05-08 2024-05-12   4 days  Moderate
#        350.125 2024-07-30 2024-08-07   8 days  Moderate
#        350.125 2024-10-20 2024-10-24   4 days  Moderate
#        350.125 2024-11-20 2024-12-31  41 days    Strong
#
# 41.875 350.375
#                date_start   date_end duration  category
# lat    lon
# 41.875 350.375 2024-01-01 2024-03-09  68 days    Strong
#        350.375 2024-04-12 2024-04-24  12 days    Strong
#        350.375 2024-05-08 2024-05-12   4 days  Moderate
#        350.375 2024-07-30 2024-08-03   4 days  Moderate
#        350.375 2024-10-19 2024-10-24   5 days  Moderate
#        350.375 2024-11-09 2024-11-13   4 days  Moderate
#        350.375 2024-11-18 2024-12-31  43 days    Strong
#
# 41.875 350.625
#                date_start   date_end duration  category
# lat    lon
# 41.875 350.625 2024-01-01 2024-01-10   9 days  Moderate
#        350.625 2024-01-15 2024-03-08  53 days    Strong
#        350.625 2024-04-12 2024-04-24  12 days  Moderate
#        350.625 2024-10-15 2024-10-24   9 days  Moderate
#        350.625 2024-11-08 2024-11-13   5 days  Moderate
#        350.625 2024-11-19 2024-12-31  42 days    Strong
#
# 41.875 350.875
#                date_start   date_end duration  category
# lat    lon
# 41.875 350.875 2024-01-22 2024-03-03  41 days    Strong
#        350.875 2024-04-12 2024-04-16   4 days  Moderate
#        350.875 2024-10-13 2024-10-25  12 days  Moderate
#        350.875 2024-11-08 2024-11-13   5 days  Moderate
#        350.875 2024-11-21 2024-12-31  40 days  Moderate
#
# 41.875 351.125
#                date_start   date_end duration  category
# lat    lon
# 41.875 351.125 2024-02-08 2024-03-02  23 days  Moderate
#        351.125 2024-04-12 2024-04-16   4 days  Moderate
#        351.125 2024-10-13 2024-10-25  12 days  Moderate
#        351.125 2024-11-08 2024-11-12   4 days  Moderate
#        351.125 2024-11-28 2024-12-10  12 days  Moderate
#
# 42.125 350.125
#                date_start   date_end duration  category
# lat    lon
# 42.125 350.125 2024-01-01 2024-03-07  66 days    Strong
#        350.125 2024-04-12 2024-04-25  13 days    Strong
#        350.125 2024-05-08 2024-05-12   4 days  Moderate
#        350.125 2024-08-03 2024-08-07   4 days  Moderate
#        350.125 2024-10-19 2024-10-25   6 days  Moderate
#        350.125 2024-10-31 2024-11-13  13 days  Moderate
#        350.125 2024-11-20 2024-12-31  41 days    Strong
#
# 42.125 350.375
#                date_start   date_end duration  category
# lat    lon
# 42.125 350.375 2024-01-01 2024-03-07  66 days    Strong
#        350.375 2024-04-12 2024-04-24  12 days  Moderate
#        350.375 2024-05-08 2024-05-12   4 days  Moderate
#        350.375 2024-10-19 2024-10-25   6 days  Moderate
#        350.375 2024-11-01 2024-11-13  12 days  Moderate
#        350.375 2024-11-20 2024-12-31  41 days    Strong
#
# 42.125 350.625
#                date_start   date_end duration  category
# lat    lon
# 42.125 350.625 2024-01-15 2024-03-07  52 days    Strong
#        350.625 2024-04-12 2024-04-23  11 days  Moderate
#        350.625 2024-10-15 2024-10-25  10 days  Moderate
#        350.625 2024-11-08 2024-11-13   5 days  Moderate
#        350.625 2024-11-20 2024-12-31  41 days    Strong
#
# 42.125 350.875
#                date_start   date_end duration  category
# lat    lon
# 42.125 350.875 2024-01-24 2024-03-03  39 days    Strong
#        350.875 2024-04-12 2024-04-23  11 days  Moderate
#        350.875 2024-10-14 2024-10-25  11 days  Moderate
#        350.875 2024-11-08 2024-11-12   4 days  Moderate
#        350.875 2024-11-21 2024-12-28  37 days  Moderate
#
# 42.125 351.125
#                date_start   date_end duration  category
# lat    lon
# 42.125 351.125 2024-02-07 2024-03-02  24 days  Moderate
#        351.125 2024-04-12 2024-04-23  11 days  Moderate
#        351.125 2024-10-13 2024-10-25  12 days  Moderate
#        351.125 2024-11-29 2024-12-10  11 days  Moderate

# %%
mhw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   time_start                      0 non-null      float64
#  1   time_end                        0 non-null      float64
#  2   time_peak                       0 non-null      float64
#  3   date_start                      0 non-null      float64
#  4   date_end                        0 non-null      float64
#  5   date_peak                       0 non-null      float64
#  6   index_start                     0 non-null      float64
#  7   index_end                       0 non-null      float64
#  8   index_peak                      0 non-null      float64
#  9   duration                        0 non-null      float64
#  10  duration_moderate               0 non-null      float64
#  11  duration_strong                 0 non-null      float64
#  12  duration_severe                 0 non-null      float64
#  13  duration_extreme                0 non-null      float64
#  14  intensity_max                   0 non-null      float64
#  15  intensity_mean                  0 non-null      float64
#  16  intensity_var                   0 non-null      float64
#  17  intensity_cumulative            0 non-null      float64
#  18  intensity_max_relThresh         0 non-null      float64
#  19  intensity_mean_relThresh        0 non-null      float64
#  20  intensity_var_relThresh         0 non-null      float64
#  21  intensity_cumulative_relThresh  0 non-null      float64
#  22  intensity_max_abs               0 non-null      float64
#  23  intensity_mean_abs              0 non-null      float64
#  24  intensity_var_abs               0 non-null      float64
#  25  intensity_cumulative_abs        0 non-null      float64
#  26  category                        0 non-null      float64
#  27  rate_onset                      0 non-null      float64
#  28  rate_decline                    0 non-null      float64
#  29  n_events                        0 non-null      int64
#  30  lat                             0 non-null      float32
#  31  lon                             0 non-null      float32
# dtypes: float32(2), float64(29), int64(1)
# memory usage: 132.0 bytes

# %% [markdown]
# ## Graphs

# %%
# =================================================
# PREP: MHW catalogue (2024 only)
# =================================================

mhw_df = mhw_all.reset_index()

mhw_df["date_start"] = pd.to_datetime(mhw_df["date_start"])
mhw_df["date_end"] = pd.to_datetime(mhw_df["date_end"])

# =================================================
# SPLIT EVENTS INTO MONTHLY DURATIONS
# =================================================

rows = []

for _, row in mhw_df.iterrows():
    start = row["date_start"]
    end = row["date_end"]
    current = start

    while current <= end:
        month_start = current.replace(day=1)
        next_month = month_start + pd.offsets.MonthBegin(1)
        month_end = min(end, next_month - pd.Timedelta(days=1))

        duration_days = (month_end - current).days + 1

        rows.append({
            "lat": row["lat"],
            "lon": row["lon"],
            "month": current.month,
            "duration_days": duration_days
        })

        current = month_end + pd.Timedelta(days=1)

monthly_events = pd.DataFrame(rows)

# =================================================
# AGGREGATE: sum DURATION PER GRID PER MONTH
# =================================================

monthly_dfs = {}

for month in range(1, 13):
    df_m = monthly_events[monthly_events["month"] == month]

    stats_m = (
        df_m
        .groupby(["lat", "lon"])
        .agg(sum_duration_days=("duration_days", "mean"))
        .reset_index()
    )

    monthly_dfs[month] = stats_m

# %%
# =================================================
# CELL-BASED MONTHLY MAPS (NO INTERPOLATION)
# =================================================

# Base grid
lons = y2024_sel["lon"].values
lats = y2024_sel["lat"].values
lon2d, lat2d = np.meshgrid(lons, lats)

# Ocean mask
ocean_mask = ~np.isnan(y2024_sel["sst"].isel(time=0).values)

# Figure
fig = plt.figure(figsize=(26, 14))
gs = GridSpec(3, 5, width_ratios=[1, 1, 1, 1, 0.05], wspace=0.15, hspace=0.25)

axes = [fig.add_subplot(gs[i // 4, i % 4], projection=ccrs.PlateCarree()) for i in range(12)]
cax = fig.add_subplot(gs[:, -1])

# Color scale
vmin = 0
vmax = max(df["sum_duration_days"].max() for df in monthly_dfs.values() if not df.empty)

month_names = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
               "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

# =================================================
# PLOT EACH MONTH
# =================================================

for ax, month in zip(axes, range(1, 13)):

    # Start with zero everywhere
    grid = np.zeros((len(lats), len(lons)))

    # Fill values for cells with MHWs
    df = monthly_dfs[month]
    for _, row in df.iterrows():
        i = np.where(lats == row["lat"])[0][0]
        j = np.where(lons == row["lon"])[0][0]
        grid[i, j] = row["sum_duration_days"]

    # Mask land only
    grid = np.ma.masked_where(~ocean_mask, grid)

    ax.set_extent(
        [lons.min(), lons.max(), lats.min(), lats.max()],
        crs=ccrs.PlateCarree()
    )

    ax.add_feature(cfeature.COASTLINE, linewidth=1)
    ax.add_feature(cfeature.BORDERS, linestyle=":", linewidth=0.8)

    mesh = ax.pcolormesh(
        lon2d, lat2d, grid,
        cmap="hot_r",
        shading="nearest",   # key line
        vmin=vmin, vmax=vmax,
        transform=ccrs.PlateCarree()
    )

    ax.set_title(month_names[month - 1])

# Colorbar + title
cbar = fig.colorbar(mesh, cax=cax)
cbar.set_label("Total MHW days in month")

fig.suptitle("2024 - Sum of Marine Heatwave Days per Month", fontsize=18, y=0.98)

plt.show()
